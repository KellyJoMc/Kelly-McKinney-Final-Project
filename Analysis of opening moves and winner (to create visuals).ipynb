# %%
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
chess = pd.read_csv("chess.csv")

# %%
import seaborn as sns

# %%
chess1 = chess[(chess['opening_name'] == "Van't Kruijs Opening")]["winner"].value_counts()

# %%
chess1
# Out:
# black    226
# white    126
# draw      16
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.title("Winner counts using Van't Kruijs Opening", fontsize=24)
plt.xlabel('Winner', fontsize=18)
plt.xticks(fontsize=8)
plt.ylabel('Count', fontsize=18)
plt.yticks(fontsize=10)
sns.barplot(x=chess1.index, y=chess1.values, palette='Greys')
plt.tight_layout()
plt.show()

# %%
beginner = chess[(chess['white_rating'] < 1200) & (chess['black_rating'] < 1200)]['opening_name'].value_counts().head(3)

# %%
beginner.head()
# Out:
# Scandinavian Defense                      33
# Van't Kruijs Opening                      28
# King's Pawn Game: Wayward Queen Attack    18
# Name: opening_name, dtype: int64

# %%
opening = chess[(chess['winner'] == "white")]['opening_name'].value_counts().head(3)

# %%
opening.head()
# Out:
# Scandinavian Defense: Mieses-Kotroc Variation    164
# Sicilian Defense                                 149
# Scotch Game                                      145
# Name: opening_name, dtype: int64

# %%
opening2 = chess[(chess['winner'] == "black")]['opening_name'].value_counts().head(3)

# %%
opening2. head()
# Out:
# Van't Kruijs Opening                226
# Sicilian Defense                    194
# Sicilian Defense: Bowdler Attack    164
# Name: opening_name, dtype: int64

# %%
opening3 = chess[(chess['winner'] == "draw")]['opening_name'].value_counts().head(3)

# %%
opening3.head()
# Out:
# Van't Kruijs Opening                16
# French Defense: Knight Variation    15
# Sicilian Defense                    15
# Name: opening_name, dtype: int64

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 5))
plt.title('Top openings that resulted in white winning', fontsize=24)
plt.xlabel('Opening name', fontsize=18)
plt.xticks(fontsize=8)
plt.ylabel('Count', fontsize=18)
plt.yticks(fontsize=10)
sns.barplot(x=opening.index, y=opening.values, palette='Greys')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.title('Top openings that resulted in black winning', fontsize=24)
plt.xlabel('Opening name', fontsize=18)
plt.xticks(fontsize=8)
plt.ylabel('Count', fontsize=18)
plt.yticks(fontsize=10)
sns.barplot(x=opening2.index, y=opening2.values, palette='Greys')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.title('Top 3 openings that resulted in a draw', fontsize=28)
plt.xlabel('Opening name', fontsize=24)
plt.xticks(fontsize=8)
plt.ylabel('Count', fontsize=24)
plt.yticks(fontsize=10)
sns.barplot(x=opening3.index, y=opening3.values, palette='magma')
plt.tight_layout()
plt.show()
